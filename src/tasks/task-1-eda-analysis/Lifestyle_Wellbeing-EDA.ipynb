# %% [markdown]
# # Omdena Egypt Roommates

# %% [markdown]
# This project will be carried out in 4 stages
#
# * **Exploratory Data Analysis: Data understanding and generating insights**
# * Data Cleaning & Data Preparation: Preparing data for Modelling
# * Data Modelling: Experimenting with different algorithms
# * Model Evaluation: Evaluate using performance metrics

# %% [markdown]
# # Lifestyle_and_Wellbeing_Data

# %% [markdown]
# **About Dataset**
#
# Latest version uploaded on 14 March 2021:
# * Added 2020 data until 14 March 2021
# * Changed label from DAILY MEDITATION to WEEKLY MEDITATION. If you refer to the survey, DAILY was a typo.
# * Added a new column with the WORK LIFE BALANCE SCORE that participants received in the first email.
#
# Context-
# * This dataset contains 15,977 survey responses with 24 attributes describing how we live our lives.
# * How can we reinvent our lifestyles to optimize our individual wellbeing while supporting the UN Sustainable Development Goals?
#
# Content
# Your Work-Life Balance survey evaluates how we thrive in both your professional and personal lives: it reflects how well you shape your lifestyle, habits and behaviors to maximize your overall life satisfaction along the following five dimensions:
#
# 1. Healthy body, reflecting your fitness and healthy habits;
# 2. Healthy mind, indicating how well you embrace positive emotions;
# 3. Expertise, measuring the ability to grow your expertise and achieve something unique;
# 4. Connection, assessing the strength of your social network and your inclination to discover the world;
# 5. Meaning, evaluating your compassion, generosity and how much 'you are living the life of your dream'.

# %% [markdown]
# # Welcome to Exploratory Data Analysis (EDA)

# %% [markdown]
# Our goal with this lecture is to "get to know" the data. Try to learn as much about the data as possible, but don't spend too much time and get stuck on this step. You will probably need to do ad-hoc data exploration later. Remember, the CRISP-DM process is iterative.

# %% [markdown]
# Import the libraries we need.

# %%
# NumPy for numerical computing
#import numpy as np

# Pandas for Data Manipulation
import pandas as pd

# Matplotlib for visualization
import matplotlib.pyplot as plt

# display plots in the notebook
# %matplotlib inline

# Seaborn for easier visualization
import seaborn as sns

# %% [markdown]
# Import the dataset.

# %%
# Load 'lifestyle.csv' in a pandas dataframe 'df'
df = pd.read_csv('lifestyle.csv')

# %% [markdown]
# The first step to understanding your dataset is to display its basic information. This will give you a high-level understanding of your dataset's structure, features, and values.

# %%
# print the dataset using .head()
pd.set_option('display.max_columns', None)
#pd.set_option('display.max_rows', None)
df.head()
# Out:
#   Timestamp  FRUITS_VEGGIES DAILY_STRESS  PLACES_VISITED  CORE_CIRCLE  \
# 0    7/7/15               3            2               2            5
# 1    7/7/15               2            3               4            3
# 2    7/7/15               2            3               3            4
# 3    7/7/15               3            3              10            3
# 4    7/7/15               5            1               3            3
#
#    SUPPORTING_OTHERS  SOCIAL_NETWORK  ACHIEVEMENT  DONATION  BMI_RANGE  \
# 0                  0               5            2         0          1
# 1                  8              10            5         2          2
# 2                  4              10            3         2          2
# 3                 10               7            2         5          2
# 4                 10               4            2         4          2
#
#    TODO_COMPLETED  FLOW  DAILY_STEPS  LIVE_VISION  SLEEP_HOURS  LOST_VACATION  \
# ...

# %%
# Display the last 5 rows of data.
df.tail()
# Out:
#           Timestamp  FRUITS_VEGGIES DAILY_STRESS  PLACES_VISITED  CORE_CIRCLE  \
# 15967  3/14/21 5:42               3            3               0            4
# 15968  3/14/21 6:30               3            3               6            8
# 15969  3/14/21 8:35               4            3               0           10
# 15970  3/14/21 8:43               1            1              10            8
# 15971  3/14/21 9:03               5            4               0            2
#
#        SUPPORTING_OTHERS  SOCIAL_NETWORK  ACHIEVEMENT  DONATION  BMI_RANGE  \
# 15967                  0              10            0         4          2
# 15968                  7               4            6         3          1
# 15969                 10               8            6         5          1
# 15970                  2               7            3         2          1
# 15971                 10              10            5         1          2
#
# ...

# %%
# look at the shape, or the dimensions of the dataset using the '.shape' attribute
# Dataframe dimensions
df.shape
# Out:
# (15972, 24)

# %% [markdown]
# Next, let's take a look at the data types of our features.

# %%
# Print column datatypes using .dtypes
df.dtypes
# Out:
# Timestamp                   object
# FRUITS_VEGGIES               int64
# DAILY_STRESS                object
# PLACES_VISITED               int64
# CORE_CIRCLE                  int64
# SUPPORTING_OTHERS            int64
# SOCIAL_NETWORK               int64
# ACHIEVEMENT                  int64
# DONATION                     int64
# BMI_RANGE                    int64
# TODO_COMPLETED               int64
# FLOW                         int64
# DAILY_STEPS                  int64
# LIVE_VISION                  int64
# SLEEP_HOURS                  int64
# LOST_VACATION                int64
# DAILY_SHOUTING               int64
# SUFFICIENT_INCOME            int64
# PERSONAL_AWARDS              int64
# TIME_FOR_PASSION             int64
# WEEKLY_MEDITATION            int64
# AGE                         object
# GENDER                      object
# WORK_LIFE_BALANCE_SCORE    float64
# dtype: object

# %% [markdown]
# **Display the formal summary statistics.**
# * Pandas comes with a .describe() function for summary statistics.

# %%
# Summarize numerical features
df.describe()
# Out:
#        FRUITS_VEGGIES  PLACES_VISITED   CORE_CIRCLE  SUPPORTING_OTHERS  \
# count    15972.000000    15972.000000  15972.000000       15972.000000
# mean         2.922677        5.232970      5.508077           5.616454
# std          1.442694        3.311912      2.840334           3.242021
# min          0.000000        0.000000      0.000000           0.000000
# 25%          2.000000        2.000000      3.000000           3.000000
# 50%          3.000000        5.000000      5.000000           5.000000
# 75%          4.000000        8.000000      8.000000          10.000000
# max          5.000000       10.000000     10.000000          10.000000
#
#        SOCIAL_NETWORK   ACHIEVEMENT      DONATION     BMI_RANGE  \
# count    15972.000000  15972.000000  15972.000000  15972.000000
# mean         6.474267      4.000751      2.715314      1.410656
# std          3.086672      2.755837      1.851586      0.491968
# min          0.000000      0.000000      0.000000      1.000000
# ...

# %% [markdown]
# Confirm missing values of the dataset

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.isnull().sum()
# Out:
# Timestamp                  0
# FRUITS_VEGGIES             0
# DAILY_STRESS               0
# PLACES_VISITED             0
# CORE_CIRCLE                0
# SUPPORTING_OTHERS          0
# SOCIAL_NETWORK             0
# ACHIEVEMENT                0
# DONATION                   0
# BMI_RANGE                  0
# TODO_COMPLETED             0
# FLOW                       0
# DAILY_STEPS                0
# LIVE_VISION                0
# SLEEP_HOURS                0
# LOST_VACATION              0
# DAILY_SHOUTING             0
# SUFFICIENT_INCOME          0
# PERSONAL_AWARDS            0
# TIME_FOR_PASSION           0
# WEEKLY_MEDITATION          0
# AGE                        0
# GENDER                     0
# WORK_LIFE_BALANCE_SCORE    0
# dtype: int64

# %% [markdown]
# Observation: There are no missing or null values in the dataset.

# %%
# Showing categorical features

df.describe(include='object')
# Out:
#        Timestamp DAILY_STRESS       AGE  GENDER
# count      15972        15972     15972   15972
# unique      7002            7         4       2
# top      7/23/18            3  21 to 35  Female
# freq         162         4398      6108    9858

# %% [markdown]
# Checking unique values of each feature

# %%
# Using the nunique function to calculate unique values

df.nunique()
# Out:
# Timestamp                  7002
# FRUITS_VEGGIES                6
# DAILY_STRESS                  7
# PLACES_VISITED               11
# CORE_CIRCLE                  11
# SUPPORTING_OTHERS            11
# SOCIAL_NETWORK               11
# ACHIEVEMENT                  11
# DONATION                      6
# BMI_RANGE                     2
# TODO_COMPLETED               11
# FLOW                         11
# DAILY_STEPS                  10
# LIVE_VISION                  11
# SLEEP_HOURS                  10
# LOST_VACATION                11
# DAILY_SHOUTING               11
# SUFFICIENT_INCOME             2
# PERSONAL_AWARDS              11
# TIME_FOR_PASSION             11
# WEEKLY_MEDITATION            11
# AGE                           4
# GENDER                        2
# WORK_LIFE_BALANCE_SCORE    1696
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
# Checking duplicate rows in the dataset

df[df.duplicated()]
# Out:
#            Timestamp  FRUITS_VEGGIES DAILY_STRESS  PLACES_VISITED  \
# 77           7/20/15               5            2              10
# 82           7/20/15               0            5               0
# 89           7/20/15               5            0               8
# 115          7/23/15               5            2              10
# 120          7/24/15               1            2               6
# ...              ...             ...          ...             ...
# 10475   3/14/19 3:28               3            3               6
# 12414   1/18/20 7:59               2            4               5
# 12758   2/25/20 3:12               4            5               3
# 14014  7/20/20 18:02               5            3               6
# 15959   3/13/21 5:46               2            5               7
#
#        CORE_CIRCLE  SUPPORTING_OTHERS  SOCIAL_NETWORK  ACHIEVEMENT  DONATION  \
# 77               1                  4               5            0         5
# ...

# %%
# Checking dataset information, to confirm missing/null values

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15972 entries, 0 to 15971
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Timestamp                15972 non-null  object
#  1   FRUITS_VEGGIES           15972 non-null  int64
#  2   DAILY_STRESS             15972 non-null  object
#  3   PLACES_VISITED           15972 non-null  int64
#  4   CORE_CIRCLE              15972 non-null  int64
#  5   SUPPORTING_OTHERS        15972 non-null  int64
#  6   SOCIAL_NETWORK           15972 non-null  int64
#  7   ACHIEVEMENT              15972 non-null  int64
#  8   DONATION                 15972 non-null  int64
#  9   BMI_RANGE                15972 non-null  int64
#  10  TODO_COMPLETED           15972 non-null  int64
#  11  FLOW                     15972 non-null  int64
#  12  DAILY_STEPS              15972 non-null  int64
#  13  LIVE_VISION              15972 non-null  int64
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# Visualising categorical features

# %%
# Visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
import plotly.express as px

# %%
# Gender count

sns.catplot(x="GENDER", kind="count", data=df)
plt.title("Gender")
plt.show()

# %%
# Stress count

sns.catplot(x="DAILY_STRESS", kind="count", data=df)
plt.title("DAILY_STRESS")
plt.show()

# %%
# Age count

sns.catplot(x="AGE", kind="count", data=df)
plt.title("Age")
plt.show()

# %% [markdown]
# Visualising numerical features

# %%
# FRUITS_VEGGIES 

sns.boxplot(x=df["FRUITS_VEGGIES"])
plt.title("FRUITS_VEGGIES")
plt.show()

# %%
# PLACES_VISITED

sns.boxplot(x=df["PLACES_VISITED"])
plt.title("PLACES_VISITED")
plt.show()

# %%
# CORE_CIRCLE

sns.boxplot(x=df["CORE_CIRCLE"])
plt.title("CORE_CIRCLE")
plt.show()

# %%
# SUPPORTING_OTHERS

sns.boxplot(x=df["SUPPORTING_OTHERS"])
plt.title("SUPPORTING_OTHERS")
plt.show()

# %%
# SOCIAL_NETWORK

sns.boxplot(x=df["SOCIAL_NETWORK"])
plt.title("SOCIAL_NETWORK")
plt.show()

# %%
# ACHIEVEMENT

sns.boxplot(x=df["ACHIEVEMENT"])
plt.title("ACHIEVEMENT")
plt.show()

# %%
# DONATION

sns.boxplot(x=df["DONATION"])
plt.title("DONATION")
plt.show()

# %%
# BMI_RANGE

sns.boxplot(x=df["BMI_RANGE"])
plt.title("BMI_RANGE")
plt.show()

# %%
# TODO_COMPLETED

sns.boxplot(x=df["TODO_COMPLETED"])
plt.title("TODO_COMPLETED")
plt.show()

# %%
# FLOW

sns.boxplot(x=df["FLOW"])
plt.title("FLOW")
plt.show()

# %%
# DAILY_STEPS

sns.boxplot(x=df["DAILY_STEPS"])
plt.title("DAILY_STEPS")
plt.show()

# %%
# LIVE_VISION

sns.boxplot(x=df["LIVE_VISION"])
plt.title("LIVE_VISION")
plt.show()

# %%
# SLEEP_HOURS

sns.boxplot(x=df["SLEEP_HOURS"])
plt.title("SLEEP_HOURS")
plt.show()

# %%
# LOST_VACATION

sns.boxplot(x=df["LOST_VACATION"])
plt.title("LOST_VACATION")
plt.show()

# %%
# DAILY_SHOUTING

sns.boxplot(x=df["DAILY_SHOUTING"])
plt.title("DAILY_SHOUTING")
plt.show()

# %%
# SUFFICIENT_INCOME

sns.boxplot(x=df["SUFFICIENT_INCOME"])
plt.title("SUFFICIENT_INCOME")
plt.show()

# %%
# PERSONAL_AWARDS

sns.boxplot(x=df["PERSONAL_AWARDS"])
plt.title("PERSONAL_AWARDS")
plt.show()

# %%
# TIME_FOR_PASSION

sns.boxplot(x=df["TIME_FOR_PASSION"])
plt.title("TIME_FOR_PASSION")
plt.show()

# %%
# WEEKLY_MEDITATION

sns.boxplot(x=df["WEEKLY_MEDITATION"])
plt.title("WEEKLY_MEDITATION")
plt.show()

# %%
# WORK_LIFE_BALANCE_SCORE

sns.boxplot(x=df["WORK_LIFE_BALANCE_SCORE"])
plt.title("WORK_LIFE_BALANCE_SCORE")
plt.show()

# %%
# Create a list of all the features
features = [
    'FRUITS_VEGGIES', 'PLACES_VISITED', 'CORE_CIRCLE', 'SUPPORTING_OTHERS',
    'SOCIAL_NETWORK', 'ACHIEVEMENT', 'DONATION', 'BMI_RANGE', 'TODO_COMPLETED',
    'FLOW', 'DAILY_STEPS', 'LIVE_VISION', 'SLEEP_HOURS', 'LOST_VACATION',
    'DAILY_SHOUTING', 'SUFFICIENT_INCOME', 'PERSONAL_AWARDS', 'TIME_FOR_PASSION',
    'WEEKLY_MEDITATION'
]

# Extract the feature values from the DataFrame
feature_values = [df[feature] for feature in features]

# %%
# Define a color palette
color_palette = sns.color_palette('Set3', n_colors=len(features))

# Create the box plot with custom colors
plt.figure(figsize=(12, 8))  # Adjust the figure size if needed
bp = plt.boxplot(feature_values, vert=False, patch_artist=True, labels=features)

# Set custom colors for the boxes
for box, color in zip(bp['boxes'], color_palette):
    box.set(facecolor=color)

plt.xlabel('Values')
plt.title('Box Plot of Numerical Features')
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# # Correlations

# %% [markdown]
# Finally, let's take a look at the relationships between numeric features and other numeric features.

# %% [markdown]
# **Correlation is a value between -1 and 1 that represents how closely values for two separate features move in unison.**
#
# * Positive correlation means that as one feature increases, the other increases.
# * E.g. a child's age and their height.
# * Negative correlation means that as one feature increases, the other decreases.
# * E.g. hours spent studying and number of parties attended.
# * Correlations near -1 or 1 indicate a strong relationship.
# * Those closer to 0 indicate a weak relationship.
# * 0 indicates no relationship.
#
# Pandas DataFrames come with a useful function for calculating correlations: .corr()

# %%
# Calculate correlations between numeric features
df.corr()
# Out:
#                          FRUITS_VEGGIES  PLACES_VISITED  CORE_CIRCLE  \
# FRUITS_VEGGIES                 1.000000        0.254889     0.157774
# PLACES_VISITED                 0.254889        1.000000     0.255877
# CORE_CIRCLE                    0.157774        0.255877     1.000000
# SUPPORTING_OTHERS              0.204461        0.237847     0.337718
# SOCIAL_NETWORK                 0.106941        0.149253     0.308657
# ACHIEVEMENT                    0.162902        0.257917     0.289417
# DONATION                       0.199457        0.204478     0.221758
# BMI_RANGE                     -0.092967       -0.108139    -0.026055
# TODO_COMPLETED                 0.227005        0.227652     0.224361
# FLOW                           0.133073        0.138559     0.237885
# DAILY_STEPS                    0.251213        0.196110     0.148006
# LIVE_VISION                    0.110105        0.143699     0.219937
# SLEEP_HOURS                    0.103627        0.127311     0.066388
# ...

# %% [markdown]
# The variable now has a big dataframe that contains all of the correlations between numeric features.
#
# That's too much information! After all, it's just a big rectangular dataset. So let's visualize this.

# %% [markdown]
# **Let's try to visualize the correlation grid and make it easier.**
#
# * Seaborn's helpful sns.heatmap() function comes handy.
# * The cmap= argument controls the color palette used in the heatmap. We will set it to the value of RdBu_r. So positive correlation values will be red and negative correlation values will be blue.

# %%
# Calculate correlations between numeric features

# Plot heatmap of correlations
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
# Make the figsize 10 x 8
plt.figure(figsize=(10,8))
# Plot heatmap of annotated correlations
sns.heatmap(df.corr() *100 , annot=True, fmt='.0f', cmap = 'RdBu_r')
# Out:
# <AxesSubplot:>
